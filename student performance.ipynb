# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
sns.heatmap(df.isnull(), cmap='BuGn')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# # boxplot

# %%
#shows if the data set has outiers
#shoes the percentile range

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='parental level of education', y='math score', data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education', y='math score', hue='gender', data=df, palette='inferno_r')
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
sns.boxplot(x='test preparation course', y='writing score', data= df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %%
sns.boxplot(x='test preparation course', y='writing score', hue='gender', data= df)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='writing score'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='reading score', y='math score', palette='inferno_r',s=100)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='math score'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='reading score', y='math score', hue='gender', palette='inferno_r',s=100)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='math score'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='reading score', y='writing score', hue='gender', palette='inferno_r',s=100)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='writing score'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='lunch', data=df)
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='lunch', y='math score', hue='gender', data=df, palette='summer')
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='math score'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='lunch', y='math score', hue='gender', data=df, palette='summer')
plt.legend(bbox_to_anchor=(1.02,1), loc=2, borderaxespad=0)

# %%
#jointplot
#combination of scattered plot and barplot(2 in 1)

# %%
sns.jointplot(x='math score', y='reading score', data=df,)

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
